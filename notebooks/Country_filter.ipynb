# %%
def country_filter(df, x):
    filter_country = df['country_code'] == 'x'
    
    return df[filter_country]

# %%
filter_spain = relevant_data['country_code'] == 'ES'
df_spain = relevant_data[filter_spain]
df_spain

# %%
import pandas as pd
data2 = pd.read_csv('../data/results/your_mvi_report.csv')
data2.head(75)
# Out:
#            Country                         Job Title  Age  Quantity  \
# 0          Belgium  8a7a3f1bce0958ae9f090683e5a925b7   21         1
# 1          Belgium  8a7a3f1bce0958ae9f090683e5a925b7   43         1
# 2          Belgium  8a7a3f1bce0958ae9f090683e5a925b7   50         1
# 3          Belgium  8a7a3f1bce0958ae9f090683e5a925b7   20         1
# 4          Czechia  8a7a3f1bce0958ae9f090683e5a925b7   38         1
# 5          Germany  8a7a3f1bce0958ae9f090683e5a925b7   36         2
# 6          Germany  8a7a3f1bce0958ae9f090683e5a925b7   51         1
# 7          Germany  8a7a3f1bce0958ae9f090683e5a925b7   44         1
# 8          Germany  8a7a3f1bce0958ae9f090683e5a925b7   48         1
# 9          Germany  8a7a3f1bce0958ae9f090683e5a925b7   50         1
# 10         Germany  8a7a3f1bce0958ae9f090683e5a925b7   36         2
# 11         Germany  8a7a3f1bce0958ae9f090683e5a925b7   49         1
# 12         Germany  8a7a3f1bce0958ae9f090683e5a925b7   35         1
# ...

# %%
country = 'Spain'
Job_title = 'Data Scientist'
chart = data2['Age'].hist(bins=50, figsize=(14, 6), facecolor='green')

chart.set_xlabel('Age')
chart.set_ylabel('Population')
chart.set_title(f'Age distribution for {Job_title} workers from {country}')
# Out:
# Text(0.5, 1.0, 'Age distribution for Data Scientist workers from Spain')

# %%
data2

# %%
def quantity_func(col):
    return col.value_counts()

# %%
def analyze(filtered_data):
    result = filtered_data.groupby(['Country', 'Age'])['Job Title'].agg(quantity_func).reset_index()
    print(result)
    return result

# %%
import numpy as np

# %%
x = np.random.randn(437)
x
# Out:
# array([-7.46638572e-01, -3.06122617e-01, -1.94289391e+00, -9.75956104e-01,
#         2.02280032e+00,  2.96676696e-01, -3.23098933e-01,  1.38246462e-01,
#        -4.16514596e-01,  7.00566394e-01,  6.85420759e-01, -1.40359157e-01,
#        -2.68778271e-01, -1.54346875e+00, -5.60728361e-01, -2.56277856e-02,
#        -1.20578861e+00, -7.36623305e-02,  6.08543109e-01,  5.24860599e-01,
#        -2.39610405e-01,  2.66290181e+00, -7.08599236e-01, -3.35688391e-01,
#         1.81718035e+00,  1.30880788e+00, -4.62472609e-01,  1.96240508e+00,
#         4.57096955e-01,  8.19099079e-02, -6.20008212e-01, -6.93605176e-01,
#        -8.11639176e-01, -2.02387624e+00,  7.41157192e-01,  5.73025440e-01,
#         1.27163797e+00, -5.17690107e-02, -6.58335235e-01, -1.94021768e+00,
#        -1.29423538e+00, -8.18250826e-01,  1.49580878e+00,  8.10807913e-01,
#         1.28571071e+00,  4.06128214e-01,  3.26139217e-02, -2.41957962e-01,
# ...
